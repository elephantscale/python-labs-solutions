# %% [markdown]
# 3-Heatmaps
# ============
#
# ### Overview
# - Learn heatmap library
#
# ### Depends On
# None
#
# ### Run time
# 10-15 mins
#
# ### Working directory
# R/08-graph

# %% [markdown]
# # Heat Map of NBA Data
#
# ## STEP 1: Read Data
# **=> Read file [data/viz/nba-2008.csv](/data/viz/nba-2008.csv) into a dataframe `nba`.**
# ```python
#     nba = pd.read_csv("/data/viz/nba-2008.csv")
# ```
#
# **=> Inspect the data frame**

# %%
import pandas as pd
nba = pd.read_csv("/data/viz/nba-2008.csv")
nba = nba.rename(columns=lambda x: x.strip())
nba
# Out:
#                   Name   G   MIN   PTS   FGM   FGA    FGP  FTM   FTA    FTP  \
# 0         Dwyane Wade   79  38.6  30.2  10.8  22.0  0.491  7.5   9.8  0.765
# 1        LeBron James   81  37.7  28.4   9.7  19.9  0.489  7.3   9.4  0.780
# 2         Kobe Bryant   82  36.2  26.8   9.8  20.9  0.467  5.9   6.9  0.856
# 3       Dirk Nowitzki   81  37.7  25.9   9.6  20.0  0.479  6.0   6.7  0.890
# 4       Danny Granger   67  36.2  25.8   8.5  19.1  0.447  6.0   6.9  0.878
# 5        Kevin Durant   74  39.0  25.3   8.9  18.8  0.476  6.1   7.1  0.863
# 6        Kevin Martin   51  38.2  24.6   6.7  15.9  0.420  9.0  10.3  0.867
# 7        Al Jefferson   50  36.6  23.1   9.7  19.5  0.497  3.7   5.0  0.738
# 8          Chris Paul   78  38.5  22.8   8.1  16.1  0.503  5.8   6.7  0.868
# 9     Carmelo Anthony   66  34.5  22.8   8.1  18.3  0.443  5.6   7.1  0.793
# 10         Chris Bosh   77  38.1  22.7   8.0  16.4  0.487  6.5   8.0  0.817
# ...

# %%
nba_indexed = nba.set_index(nba['Name']).drop('Name', axis=1)
nba_indexed
# Out:
#                      G   MIN   PTS   FGM   FGA    FGP  FTM   FTA    FTP  3PM  \
# Name
# Dwyane Wade         79  38.6  30.2  10.8  22.0  0.491  7.5   9.8  0.765  1.1
# LeBron James        81  37.7  28.4   9.7  19.9  0.489  7.3   9.4  0.780  1.6
# Kobe Bryant         82  36.2  26.8   9.8  20.9  0.467  5.9   6.9  0.856  1.4
# Dirk Nowitzki       81  37.7  25.9   9.6  20.0  0.479  6.0   6.7  0.890  0.8
# Danny Granger       67  36.2  25.8   8.5  19.1  0.447  6.0   6.9  0.878  2.7
# Kevin Durant        74  39.0  25.3   8.9  18.8  0.476  6.1   7.1  0.863  1.3
# Kevin Martin        51  38.2  24.6   6.7  15.9  0.420  9.0  10.3  0.867  2.3
# Al Jefferson        50  36.6  23.1   9.7  19.5  0.497  3.7   5.0  0.738  0.0
# Chris Paul          78  38.5  22.8   8.1  16.1  0.503  5.8   6.7  0.868  0.8
# Carmelo Anthony     66  34.5  22.8   8.1  18.3  0.443  5.6   7.1  0.793  1.0
# Chris Bosh          77  38.1  22.7   8.0  16.4  0.487  6.5   8.0  0.817  0.2
# ...

# %% [markdown]
# ## STEP 2) Sort
# **=> sort nba data frame by `PTS` column.**
# Hint: `sort([column])`
# ```python
#     nba.sort_values(['PTS'])
# ```

# %%
# TODO: Sort datafram
nba_indexed = nba_indexed.sort_values(['PTS'], ascending = False)
nba_indexed
# Out:
#                      G   MIN   PTS   FGM   FGA    FGP  FTM   FTA    FTP  3PM  \
# Name
# Dwyane Wade         79  38.6  30.2  10.8  22.0  0.491  7.5   9.8  0.765  1.1
# LeBron James        81  37.7  28.4   9.7  19.9  0.489  7.3   9.4  0.780  1.6
# Kobe Bryant         82  36.2  26.8   9.8  20.9  0.467  5.9   6.9  0.856  1.4
# Dirk Nowitzki       81  37.7  25.9   9.6  20.0  0.479  6.0   6.7  0.890  0.8
# Danny Granger       67  36.2  25.8   8.5  19.1  0.447  6.0   6.9  0.878  2.7
# Kevin Durant        74  39.0  25.3   8.9  18.8  0.476  6.1   7.1  0.863  1.3
# Kevin Martin        51  38.2  24.6   6.7  15.9  0.420  9.0  10.3  0.867  2.3
# Al Jefferson        50  36.6  23.1   9.7  19.5  0.497  3.7   5.0  0.738  0.0
# Chris Paul          78  38.5  22.8   8.1  16.1  0.503  5.8   6.7  0.868  0.8
# Carmelo Anthony     66  34.5  22.8   8.1  18.3  0.443  5.6   7.1  0.793  1.0
# Chris Bosh          77  38.1  22.7   8.0  16.4  0.487  6.5   8.0  0.817  0.2
# ...

# %%
# %matplotlib inline
import seaborn as sns
import matplotlib.pyplot as plt
sns.set()
fig=plt.figure(figsize=(26, 20), dpi= 80, facecolor='w', edgecolor='k')
fig, ax = plt.subplots()
fig.set_size_inches(8., 8.)
sns.heatmap(nba_indexed, cbar=False)
sns.despine()

# %% [markdown]
# ### What happened?
#
# Oops!  Looks like our heatmap is entirely focused on the stats for Games. That's the one with the largest magnitude.  Let's try to normalize this.
#
# Here's the formula.
#
# (Column Val - Mean() ) / Std
#
# You can call this on the entire colums:
#
# ```python
# (df - df.mean())/df.std()
# ```

# %%
# Now if we normalize it by column:
df_norm_col= (nba_indexed - nba_indexed.mean())/nba_indexed.std()
df_norm_col
# Out:
#                            G       MIN       PTS       FGM       FGA  \
# Name
# Dwyane Wade         0.617930  1.001970  3.179941  2.920022  2.596832
# LeBron James        0.769383  0.611930  2.566974  1.957185  1.697237
# Kobe Bryant         0.845110 -0.038137  2.022113  2.044716  2.125615
# Dirk Nowitzki       0.769383  0.611930  1.715629  1.869654  1.740075
# Danny Granger      -0.290791 -0.038137  1.681575  0.906817  1.354534
# Kevin Durant        0.239296  1.175321  1.511307  1.256940  1.226020
# Kevin Martin       -1.502418  0.828619  1.272930 -0.668734 -0.016278
# Al Jefferson       -1.578145  0.135214  0.762123  1.957185  1.525885
# Chris Paul          0.542203  0.958632  0.659962  0.556695  0.069397
# Carmelo Anthony    -0.366517 -0.774880  0.659962  0.556695  1.011831
# Chris Bosh          0.466477  0.785281  0.625908  0.469164  0.197911
# Brandon Roy         0.542203  0.395241  0.591855  0.556695  0.412100
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.set()
fig=plt.figure(figsize=(26, 20), dpi= 80, facecolor='w', edgecolor='k')
fig, ax = plt.subplots()
fig.set_size_inches(8., 8.)
sns.heatmap(df_norm_col, cbar=False)
sns.despine()
